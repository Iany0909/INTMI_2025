# %% [markdown]
# <a href="https://colab.research.google.com/github/Iany0909/INTMI_2025/blob/main/30-10-2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Olá mundo')
# Out:
# Olá mundo

# %%
x = 5
x = 10
(print(x))
# Out:
# 10

# %%
# Exemplo de sobrescrita de váriavel
x = 5 # a váriavel recebeu o valor de 5.
x = 10 # a váriavel passou a ser 10
print(x) #imprime o valor de x
# Out:
# 10

# %%
num1 = 10
num2 = 15
print (num1 + num2)
# Out:
# 25

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o primeiro número: '))
print('A resposta é',num1 + num2)
# Out:
# Digite o primeiro número: 24
# Digite o primeiro número: 13
# A resposta é 37

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o primeiro número: '))
print('A resposta é',num1 * num2)
# Out:
# Digite o primeiro número: 3
# Digite o primeiro número: 6897
# A resposta é 20691

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o primeiro número: '))
num3 = int(input('Digite o primeiro número: '))
print('A resposta é',(num1 + num2 + num3)/3)
# Out:
# Digite o primeiro número: 30
# Digite o primeiro número: 60
# Digite o primeiro número: 90
# A resposta é 60.0

# %%
num1 = int(input('Digite o primeiro número: '))
print( 'A resposta é' ,(num1)*2)
# Out:
# Digite o primeiro número: -85
# A resposta é -170

# %%
num1 = int(input('Digite o primeiro número: '))
print( 'A resposta é' ,(num1)**2)
# Out:
# Digite o primeiro número: 3
# A resposta é 9

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o primeiro número: '))
print('A resposta é',(num1)%(num2))
# Out:
# Digite o primeiro número: 8
# Digite o primeiro número: 4
# A resposta é 0

# %%
# Exemplo com números inteiros e de ponto flutuante
(abs(-10)) # 'A resposta é' ,10
(abs(5.5)) # 'A resposta é' ,5.5
num1 = int(input('Digite o primeiro número: '))
print('A resposta é' ,(abs(num1)))
# Out:
# Digite o primeiro número: -8
# A resposta é 8

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o primeiro número: '))
print('A resposta é',(num1)//(num2))
# Out:
# Digite o primeiro número: 90
# Digite o primeiro número: 10
# A resposta é 9

# %%
(abs(-10)) # 'A resposta é' ,10
(abs(5.5)) # 'A resposta é' ,5.5
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o primeiro número: '))
print('A resposta é',(abs(num1+num2)))
# Out:
# Digite o primeiro número: 10
# Digite o primeiro número: -20
# A resposta é 10

# %%
idade = int (input( "Digite sua idade " ))
if idade >=18:
  print("Você é maior de idade")
else:
  print('Você nâo é maior de idade')
# Out:
# Digite sua idade 76
# Você é maior de idade

# %%
idade = int (input( "Digite sua idade " ))
if idade >=18:
  print("Adulto.")
elif idade >=14:
  print("Junior")
else:
  print("Infantil")
# Out:
# Digite sua idade 4
# Infantil

# %%
nome = str(input("Digite seu nome "))
if 'k'in nome:
  print('O nome tem a letra k')
else:
  print('O nome não tem a letra k')
# Out:
# Digite seu nomeIany
# O nome não tem a letra k

# %%
idade = int (input( "Digite sua idade " ))
if idade >=18:
  print("Você é maior de idade")
else:
  print('Você nâo é maior de idade')
# Out:
# Digite sua idade 76
# Você é maior de idade

# %%
num = int (input( "Digite um número " ))
if num >10:
  print("Esse número é maior que 10")
else:
  print("Esse número não é maior que 10")
# Out:
# Digite um número 9
# Esse número não é maior que 10

# %%
numero = int(input("Digite um número inteiro: "))
# Verifica se o número é divisível por 2
if numero % 2 == 0:
    print(f"O número {numero} é par.")
else:
    print(f"O número {numero} é ímpar.")
# Out:
# Digite um número inteiro: 9
# O número 9 é ímpar.

# %%
nome = str(input("Digite um nome "))
if 'a'in nome:
  print('O nome tem a letra a')
else:
  print('O nome não tem a letra a')
# Out:
# Digite seu nome Iany
# O nome tem a letra a

# %%
numero = int(input("Digite um número inteiro: "))
# Verifica se o número é dívisivel por 5
if numero % 5 == 0:
    print(f"O número {numero} é múltiplo de 5.")
else:
    print(f"O número {numero} é múltiplo.")
# Out:
# Digite um número inteiro: 25
# O número 25 é múltiplo de 5.

# %%
temp = float(input("Digite a temperatura atual "))
if temp >30:
 print("Está quente.")
else:
 print("Está frio." )
# Out:
# Digite a temperatura atual 27
# Está frio.

# %%
opcao = input('Digite "S" para continuar ou "N" para sair: ').strip().upper()

if opcao == "S":
    print("Você escolheu continuar.")
elif opcao == "N":
    print("Você escolheu sair.")
else:
    print("Opção inválida.")
# Out:
# Digite "S" para continuar ou "N" para sair: N
# Você escolheu sair.

# %%
numero = float(input("Digite um número: "))

if numero > 0:
    print("O número é positivo.")
elif numero < 0:
    print("O número é negativo.")
else:
    print("O número é zero.")
# Out:
# Digite um número: 8
# O número é positivo.

# %%
dias = ["Domingo", "Segunda-feira", "Terça-feira", "Quarta-feira",
        "Quinta-feira", "Sexta-feira", "Sábado"]

numero = int(input("Digite um número de 1 a 7: "))

if 1 <= numero <= 7:
    print(dias[numero - 1])
else:
    print("Número inválido! Digite um número entre 1 e 7.")
# Out:
# Digite um número de 1 a 7: 6
# Sexta-feira

# %%
# Programa para verificar se um ano é bissexto
ano = int(input("Digite um ano: "))
# Verifica se o ano é bissexto
if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print(f"{ano} é um ano bissexto.")
else:
    print(f"{ano} não é um ano bissexto.")
# Out:
# Digite um ano: 2025
# 2025 não é um ano bissexto.

# %%
# Solicita os dados ao usuário
horas_trabalhadas = float(input("Digite a quantidade de horas trabalhadas: "))
valor_hora = float(input("Digite o valor recebido por hora: "))

# Verifica se há horas extras
if horas_trabalhadas <= 40:
    salario = horas_trabalhadas * valor_hora
else:
    horas_extras = horas_trabalhadas - 40
    salario = (40 * valor_hora) + (horas_extras * valor_hora * 1.5)

# Exibe o resultado
print(f"Seu salário total é: R$ {salario:.2f}")
# Out:
# Digite a quantidade de horas trabalhadas: 45
# Digite o valor recebido por hora: 100
# Seu salário total é: R$ 4750.00
